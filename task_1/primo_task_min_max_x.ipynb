# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Load Data

# %%
train_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DL_Project/task_1/train.csv', sep = ',')
test_df  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DL_Project/task_1/test.csv', sep = ',')

# %%
train_col = train_df['x']
test_col  = train_df['x']

# %% [markdown]
# ## Split the data

# %%
n = len(train_df)

train_data = train_col[0          : int(n*0.8)].to_numpy()
valid_data = train_col[int(n*0.8) :           ].to_numpy()

test_data  = test_col.to_numpy()

# %%
train_data.shape, valid_data.shape, test_data.shape
# Out:
# ((115928,), (28983,), (144911,))

# %% [markdown]
# ## Min Max scale

# %%
scaler = MinMaxScaler(feature_range=(-1,1))

sv = scaler.fit_transform(train_data.reshape(-1, 1))
sv = np.reshape(sv, len(sv))
train = sv

sv = scaler.transform(valid_data.reshape(-1, 1))
sv = np.reshape(sv, len(sv))
valid = sv

sv = scaler.transform(test_data.reshape(-1, 1))
sv = np.reshape(sv, len(sv))
test = sv

# %%
train.shape, valid.shape, test.shape
# Out:
# ((115928,), (28983,), (144911,))

# %%
train = train.reshape((train.shape[0], 1))
valid = valid.reshape((valid.shape[0], 1))
test  = test.reshape((test.shape[0]  , 1))

# %%
train.shape, valid.shape, test.shape
# Out:
# ((115928, 1), (28983, 1), (144911, 1))

# %% [markdown]
# # Data windowing

# %%
def split(data, win_size=30, win_shift=6, offset=1):

  rows = np.arange(win_size, len(data) - win_shift - 1, win_shift)

  samples = np.zeros((len(rows), win_size, data.shape[-1]))
  targets = np.zeros((len(rows),))

  for j, row in enumerate(rows):
    samples[j] = data[j * win_shift: row]
    targets[j] = data[row: row + offset]

  return samples, targets

# %% [markdown]
# # Window 5 min Shift 1 min

# %% [markdown]
# ## Single Output Models

# %%
x_train, y_train = split(train)
x_valid, y_valid = split(valid)
x_test , y_test  = split(test)

# %%
x_train.shape, y_train.shape
# Out:
# ((19316, 30, 1), (19316,))

# %%
x_valid.shape, y_valid.shape
# Out:
# ((4825, 30, 1), (4825,))

# %%
x_test.shape, y_test.shape
# Out:
# ((24146, 30, 1), (24146,))

# %%
seq_len  = x_train.shape[1]
num_feat = x_train.shape[2]

# %% [markdown]
# ### Recurrent

# %%
lstm = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(16, input_shape = (seq_len, num_feat), return_sequences=True),
    tf.keras.layers.LSTM(8),
    tf.keras.layers.Dense(1, activation='tanh')
])

lstm.compile(loss = 'mae', optimizer='adam')
history = lstm.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose = 1, batch_size=32, shuffle=False)
# Out:
# Epoch 1/100
# 604/604 [==============================] - 32s 41ms/step - loss: 0.1312 - val_loss: 0.0898
# Epoch 2/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0946 - val_loss: 0.0836
# Epoch 3/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0787 - val_loss: 0.0692
# Epoch 4/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0685 - val_loss: 0.0745
# Epoch 5/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0641 - val_loss: 0.0714
# Epoch 6/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0612 - val_loss: 0.0623
# Epoch 7/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0579 - val_loss: 0.0553
# Epoch 8/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0577 - val_loss: 0.0492
# Epoch 9/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0569 - val_loss: 0.0537
# Epoch 10/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0570 - val_loss: 0.0537
# Epoch 11/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0565 - val_loss: 0.0612
# Epoch 12/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0568 - val_loss: 0.0479
# Epoch 13/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0568 - val_loss: 0.0538
# Epoch 14/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0555 - val_loss: 0.0486
# Epoch 15/100
# 604/604 [==============================] - 17s 27ms/step - loss: 0.0572 - val_loss: 0.0605
# Epoch 16/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0554 - val_loss: 0.0565
# Epoch 17/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0566 - val_loss: 0.0628
# Epoch 18/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0554 - val_loss: 0.0561
# Epoch 19/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0556 - val_loss: 0.0593
# Epoch 20/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0572 - val_loss: 0.0502
# Epoch 21/100
# 604/604 [==============================] - 15s 26ms/step - loss: 0.0546 - val_loss: 0.0515
# Epoch 22/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0564 - val_loss: 0.0526
# Epoch 23/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0558 - val_loss: 0.0492
# Epoch 24/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0556 - val_loss: 0.0507
# Epoch 25/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0554 - val_loss: 0.0490
# Epoch 26/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0556 - val_loss: 0.0493
# Epoch 27/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0553 - val_loss: 0.0496
# Epoch 28/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0554 - val_loss: 0.0566
# Epoch 29/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0538 - val_loss: 0.0473
# Epoch 30/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0547 - val_loss: 0.0545
# Epoch 31/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0554 - val_loss: 0.0574
# Epoch 32/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0541 - val_loss: 0.0478
# Epoch 33/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0551 - val_loss: 0.0484
# Epoch 34/100
# 604/604 [==============================] - 16s 26ms/step - loss: 0.0547 - val_loss: 0.0516
# Epoch 35/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0544 - val_loss: 0.0554
# Epoch 36/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0546 - val_loss: 0.0512
# Epoch 37/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0538 - val_loss: 0.0471
# Epoch 38/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0549 - val_loss: 0.0548
# Epoch 39/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0539 - val_loss: 0.0553
# Epoch 40/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0542 - val_loss: 0.0548
# Epoch 41/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0538 - val_loss: 0.0555
# Epoch 42/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0537 - val_loss: 0.0517
# Epoch 43/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0542 - val_loss: 0.0509
# Epoch 44/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0539 - val_loss: 0.0492
# Epoch 45/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0539 - val_loss: 0.0517
# Epoch 46/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0533 - val_loss: 0.0490
# Epoch 47/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0534 - val_loss: 0.0481
# Epoch 48/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0541 - val_loss: 0.0493
# Epoch 49/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0539 - val_loss: 0.0548
# Epoch 50/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0534 - val_loss: 0.0481
# Epoch 51/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0534 - val_loss: 0.0507
# Epoch 52/100
# 604/604 [==============================] - 16s 27ms/step - loss: 0.0539 - val_loss: 0.0512
# Epoch 53/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0533 - val_loss: 0.0468
# Epoch 54/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0535 - val_loss: 0.0555
# Epoch 55/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0529 - val_loss: 0.0474
# Epoch 56/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0530 - val_loss: 0.0507
# Epoch 57/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0527 - val_loss: 0.0467
# Epoch 58/100
# 604/604 [==============================] - 26s 42ms/step - loss: 0.0526 - val_loss: 0.0537
# Epoch 59/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0533 - val_loss: 0.0528
# Epoch 60/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0531 - val_loss: 0.0534
# Epoch 61/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0531 - val_loss: 0.0512
# Epoch 62/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0526 - val_loss: 0.0483
# Epoch 63/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0535 - val_loss: 0.0469
# Epoch 64/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0526 - val_loss: 0.0483
# Epoch 65/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0529 - val_loss: 0.0521
# Epoch 66/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0529 - val_loss: 0.0474
# Epoch 67/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0530 - val_loss: 0.0475
# Epoch 68/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0526 - val_loss: 0.0478
# Epoch 69/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0532 - val_loss: 0.0481
# Epoch 70/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0534 - val_loss: 0.0536
# Epoch 71/100
# 604/604 [==============================] - 15s 26ms/step - loss: 0.0527 - val_loss: 0.0498
# Epoch 72/100
# 604/604 [==============================] - 16s 26ms/step - loss: 0.0525 - val_loss: 0.0521
# Epoch 73/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0528 - val_loss: 0.0521
# Epoch 74/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0525 - val_loss: 0.0475
# Epoch 75/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0524 - val_loss: 0.0486
# Epoch 76/100
# 604/604 [==============================] - 14s 24ms/step - loss: 0.0528 - val_loss: 0.0470
# Epoch 77/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0526 - val_loss: 0.0509
# Epoch 78/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0527 - val_loss: 0.0490
# Epoch 79/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0529 - val_loss: 0.0472
# Epoch 80/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0528 - val_loss: 0.0489
# Epoch 81/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0530 - val_loss: 0.0466
# Epoch 82/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0522 - val_loss: 0.0472
# Epoch 83/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0527 - val_loss: 0.0511
# Epoch 84/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0525 - val_loss: 0.0491
# Epoch 85/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0526 - val_loss: 0.0518
# Epoch 86/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0530 - val_loss: 0.0502
# Epoch 87/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0529 - val_loss: 0.0470
# Epoch 88/100
# 604/604 [==============================] - 14s 24ms/step - loss: 0.0524 - val_loss: 0.0506
# Epoch 89/100
# 604/604 [==============================] - 16s 27ms/step - loss: 0.0524 - val_loss: 0.0471
# Epoch 90/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0530 - val_loss: 0.0497
# Epoch 91/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0524 - val_loss: 0.0462
# Epoch 92/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0523 - val_loss: 0.0469
# Epoch 93/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0525 - val_loss: 0.0465
# Epoch 94/100
# 604/604 [==============================] - 15s 25ms/step - loss: 0.0530 - val_loss: 0.0490
# Epoch 95/100
# 604/604 [==============================] - 14s 24ms/step - loss: 0.0523 - val_loss: 0.0474
# Epoch 96/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0526 - val_loss: 0.0511
# Epoch 97/100
# 604/604 [==============================] - 14s 24ms/step - loss: 0.0520 - val_loss: 0.0462
# Epoch 98/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0520 - val_loss: 0.0470
# Epoch 99/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0524 - val_loss: 0.0513
# Epoch 100/100
# 604/604 [==============================] - 15s 24ms/step - loss: 0.0523 - val_loss: 0.0469

# %%
loss = history.history['loss'] 
val_loss = history.history['val_loss']
epochs = range(len(loss)) 

plt.figure(figsize=(8,7))
plt.plot(epochs, loss,  label='Training loss') 
plt.plot(epochs, val_loss,  label='Validation loss') 
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing

# %%
prediction_lstm = lstm.predict(x_test)

# %% [markdown]
# **Revert scaling**

# %%
y_test = y_test.reshape((y_test.shape[0], 1))

# %%
y_test          = scaler.inverse_transform(y_test)
prediction_lstm = scaler.inverse_transform(prediction_lstm)

# %% [markdown]
# **Calculate the Mean Absolute Error**

# %%
y_test          = y_test.reshape((y_test.shape[0]))
prediction_lstm = prediction_lstm.reshape((prediction_lstm.shape[0]))

# %%
mae_lstm = mean_absolute_error(prediction_lstm, y_test)

print(f"Mean Absolute Error Recurrent Network: {mae_lstm}")
# Out:
# Mean Absolute Error Recurrent Network: 54.548088672548744
